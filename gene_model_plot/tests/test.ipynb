# %%
from gene_model_plot.gene_model import GeneModel

# %%
# initialize the GeneModel object with the GTF file 
# to create the gene model object
gmo = GeneModel("gencode.v43.annotation.gtf", vcf_file_or_dir="vcfs_pseudou")

# %%
gmo.plot("ENST00000339475.10")

# %%
gmo.plot("ENST00000339475.10", highlight_genomic_pos=56804135)

# %%
gmo.plot("ENST00000339475.10", highlight_relative_pos=1000)

# %%
gmo.plot("ENST00000645609.1", highlight_relative_pos=200)
